# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Loading the given Dataset

# %%
df=pd.read_csv("Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.shape #checking the shape of the dataset
# Out:
# (10000, 14)

# %% [markdown]
# # 1.univariate Analysis

# %%
#Histogram 
sns.histplot(df["Age"],color='purple')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
#Histogram on Categorical variables
sns.histplot(x='Age',data=df, hue=df['Tenure'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
#Distplot
sns.displot(df["Age"],color='yellow')

# %%
#Boxplot
sns.boxplot(df["Age"],color='red')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # 2.Bivariate Analysis

# %%
#Barplot
sns.barplot(df["Tenure"],df["Age"])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tenure', ylabel='Age'>

# %%
#Linearplot
sns.lineplot(df["Age"],df["Tenure"], color='blue')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Tenure'>

# %%
#Scatterplot
sns.scatterplot(x=df.Age,y=df.RowNumber,color='green')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='RowNumber'>

# %%
#Regplot
sns.regplot(df['Age'],df['Tenure'],color='pink')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Tenure'>

# %% [markdown]
# # 3.Multivariate Analysis

# %%
#Pairplot
sns.pairplot(data=df[["RowNumber","Age","Tenure","Balance","NumOfProducts"]])

# %% [markdown]
# # 4.Performing Descriptive Statics

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# # 5.Handling missing values

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # 6.Find the outliers and replace the outliers

# %%
outliers=df.quantile(q=(0.25,0.75))

# %%
outliers
# Out:
#       RowNumber   CustomerId  CreditScore   Age  Tenure    Balance  \
# 0.25    2500.75  15628528.25        584.0  32.0     3.0       0.00
# 0.75    7500.25  15753233.75        718.0  44.0     7.0  127644.24
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0.25            1.0        0.0             0.0       51002.1100     0.0
# 0.75            2.0        1.0             1.0      149388.2475     0.0

# %%
# Finding inter-quartile range
q1 = df.CreditScore.quantile(0.25)
q3 = df.CreditScore.quantile(0.75)
IQR = q3 - q1
lower_limit = q1 - 1.5 * IQR

# %%
# Median values
df.median(numeric_only=True)
# Out:
# RowNumber          5.000500e+03
# CustomerId         1.569074e+07
# CreditScore        6.520000e+02
# Age                3.700000e+01
# Tenure             5.000000e+00
# Balance            9.719854e+04
# NumOfProducts      1.000000e+00
# HasCrCard          1.000000e+00
# IsActiveMember     1.000000e+00
# EstimatedSalary    1.001939e+05
# Exited             0.000000e+00
# dtype: float64

# %%
#Replacing the outliers
df['CreditScore'] = np.where(df['CreditScore'] < lower_limit, 7, df['CreditScore'])
sns.boxplot(x=df.CreditScore)
# Out:
# <AxesSubplot:xlabel='CreditScore'>

# %% [markdown]
# # 7.Checking for categorical columns and performing encoding

# %%
df.head()
#Here we can see the presence of categorical columns such as Geography and Gender
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df.Gender = le.fit_transform(df.Gender)
df.Geography = le.fit_transform(df.Geography)

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619          0       0   42
# 1          2    15647311      Hill          608          2       0   41
# 2          3    15619304      Onio          502          0       0   42
# 3          4    15701354      Boni          699          0       0   39
# 4          5    15737888  Mitchell          850          2       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# # 8.Splitting into independent (x) and Dependent(Y) variable

# %%
y = df["Surname"]
y.head()
# Out:
# 0    Hargrave
# 1        Hill
# 2        Onio
# 3        Boni
# 4    Mitchell
# Name: Surname, dtype: object

# %%
x=df.drop(columns=["Surname"],axis=1)
x.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure  \
# 0          1    15634602          619          0       0   42       2
# 1          2    15647311          608          2       0   41       1
# 2          3    15619304          502          0       0   42       8
# 3          4    15701354          699          0       0   39       1
# 4          5    15737888          850          2       0   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# # 9.scaling the independent variables

# %%
from sklearn.preprocessing import scale
X_Scaled = pd.DataFrame(scale(x), columns=x.columns)
X_Scaled.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Geography    Gender       Age  \
# 0  -1.731878   -0.783213    -0.312543  -0.901886 -1.095988  0.293517
# 1  -1.731531   -0.606534    -0.423455   1.515067 -1.095988  0.198164
# 2  -1.731185   -0.995885    -1.492245  -0.901886 -1.095988  0.293517
# 3  -1.730838    0.144767     0.494090  -0.901886 -1.095988  0.007457
# 4  -1.730492    0.652659     2.016611   1.515067 -1.095988  0.388871
#
#      Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0 -1.041760 -1.225848      -0.911583   0.646092        0.970243
# 1 -1.387538  0.117350      -0.911583  -1.547768        0.970243
# 2  1.032908  1.333053       2.527057   0.646092       -1.030670
# 3 -1.387538 -1.225848       0.807737  -1.547768       -1.030670
# 4 -1.041760  0.785728      -0.911583   0.646092        0.970243
#
#    EstimatedSalary    Exited
# 0         0.021886  1.977165
# 1         0.216534 -0.505775
# 2         0.240687  1.977165
# 3        -0.108918 -0.505775
# 4        -0.365276 -0.505775

# %% [markdown]
# # 10.Training and Testing split

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X_Scaled, y, test_size=0.2, random_state=0)

# %%
X_Train.shape
# Out:
# (8000, 13)

# %%
X_Test.shape
# Out:
# (2000, 13)

# %%
Y_Train.shape
# Out:
# (8000,)

# %%
Y_Test.shape
# Out:
# (2000,)

# %%
X_Train.head()
# Out:
#       RowNumber  CustomerId  CreditScore  Geography    Gender       Age  \
# 7389   0.827747   -0.195066     0.171437   1.515067 -1.095988 -0.469311
# 9275   1.481077    0.810821    -2.248463   0.306591  0.912419  0.293517
# 2995  -0.694379   -1.507642    -1.159508  -0.901886 -1.095988 -0.946079
# 5316   0.109639    1.243462     0.040359   1.515067  0.912419  0.102810
# 356   -1.608556   -1.100775     2.016611   1.515067 -1.095988  1.723821
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7389 -0.004426 -1.225848       0.807737   0.646092       -1.030670
# 9275 -1.387538 -0.012892      -0.911583   0.646092        0.970243
# 2995 -1.041760  0.575076      -0.911583   0.646092       -1.030670
# 5316 -0.004426  0.467955      -0.911583   0.646092       -1.030670
# 356   1.032908  0.806010       0.807737   0.646092        0.970243
#
#       EstimatedSalary    Exited
# 7389         1.108382 -0.505775
# 9275        -0.747592 -0.505775
# 2995         1.487464 -0.505775
# 5316         1.278558 -0.505775
# 356          0.560069 -0.505775

# %%
X_Test.head()
# Out:
#       RowNumber  CustomerId  CreditScore  Geography    Gender       Age  \
# 9394   1.522299   -1.045250    -0.534367   0.306591 -1.095988 -0.373958
# 898   -1.420801   -0.503813    -1.280503  -0.901886 -1.095988  0.102810
# 2398  -0.901186   -0.793292     0.564671   1.515067 -1.095988  0.293517
# 5906   0.314021    0.760190     1.391470  -0.901886  0.912419 -0.660018
# 2343  -0.920239    1.042107     0.564671   0.306591  0.912419 -0.087897
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9394  1.032908  0.875323      -0.911583   0.646092        0.970243
# 898  -1.041760  0.424422      -0.911583   0.646092       -1.030670
# 2398  1.032908  0.302927      -0.911583   0.646092        0.970243
# 5906 -0.350204  0.570464      -0.911583  -1.547768       -1.030670
# 2343 -0.004426  1.387129       0.807737   0.646092        0.970243
#
#       EstimatedSalary    Exited
# 9394         1.613046 -0.505775
# 898          0.497532  1.977165
# 2398        -0.423561 -0.505775
# 5906        -0.186439 -0.505775
# 2343         0.618560 -0.505775

# %%
Y_Train.head()
# Out:
# 7389     Mishin
# 9275    Carslaw
# 2995      Moore
# 5316      Ferri
# 356     Simmons
# Name: Surname, dtype: object

# %%
Y_Test.head()
# Out:
# 9394    Upchurch
# 898      Fallaci
# 2398    Morrison
# 5906     Worsnop
# 2343      Gibson
# Name: Surname, dtype: object
